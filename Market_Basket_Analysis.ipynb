# %% [markdown]
# # Importing Libraries

# %%
import numpy as np  
import matplotlib.pyplot as plt  
import pandas as pd
from apyori import apriori

# %% [markdown]
# # Reading Data

# %%
data = pd.read_csv("Market Basket Analysis.csv",header = None)
print(data.head())
# Out:
#          0                1              2              3          4  \
# 0   Camera  Battery standby  Build quality          Price  Processor
# 1  Storage              NaN            NaN            NaN        NaN
# 2   Camera  Battery standby        Display          Price    Storage
# 3   Camera  Battery standby        Display  Build quality      Price
# 4   Camera  Battery standby        Display          Price  Processor
#
#                5          6              7              8    9
# 0      OS and UI   Security            NaN            NaN  NaN
# 1            NaN        NaN            NaN            NaN  NaN
# 2  Sound quality        NaN            NaN            NaN  NaN
# 3      Processor    Storage      OS and UI  Sound quality  NaN
# 4        Storage  OS and UI  Sound quality            NaN  NaN

# %% [markdown]
# # Building Association Rule

# %%
records = []  
for i in range(0, 56):  
    records.append([str(data.values[i,j]) for j in range(0, 10)])


association_rules = apriori(records, min_support=0.01, min_confidence=0.6, min_lift=3, min_length=2)  
association_results = list(association_rules)

rows = []

for item in association_results:
    # first index of the inner list
    # Contains base item and add item
    pair = item[0] 
    items = [x for x in pair]
    print("=====================================")
    print("Rule: " + items[0] + " -> " + items[1])
    
    #second index of the inner list
    print("Support: " + str(item[1]))
    #third index of the list located at 0th
    #of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
    rows.append([items[0], items[1], item[1], item[2][0][2], item[2][0][3]])
# Out:
# ...
# Rule: Display -> OS and UI
# Support: 0.19642857142857142
# Confidence: 0.9166666666666667
# Lift: 3.0196078431372553
# ...
# Rule: Display -> OS and UI
# Support: 0.19642857142857142
# Confidence: 0.9166666666666667
# Lift: 3.0196078431372553
# ...
# Rule: Display -> OS and UI
# Support: 0.16071428571428573
# Confidence: 0.6428571428571429
# Lift: 3.0000000000000004
# ...
# Rule: Display -> OS and UI
# Support: 0.19642857142857142
# Confidence: 0.9166666666666667
# Lift: 3.0196078431372553
# ...
# Rule: Display -> Camera
# Support: 0.16071428571428573
# Confidence: 0.6428571428571429
# Lift: 3.0000000000000004
# ...
# Rule: Camera -> Storage
# Support: 0.16071428571428573
# Confidence: 0.7500000000000001
# Lift: 3.0000000000000004
# ...
# Rule: Display -> OS and UI
# Support: 0.16071428571428573
# Confidence: 0.6000000000000001
# Lift: 3.054545454545455
# ...
# Rule: Display -> Storage
# Support: 0.16071428571428573
# Confidence: 0.7500000000000001
# Lift: 3.0000000000000004
# ...
# Rule: OS and UI -> Storage
# ...

# %% [markdown]
# # Creating Dataframe from the Output

# %%
df = pd.DataFrame(rows, columns=['LHS','RHS','Support','Confidence','Lift'])
df.head()
# Out:
#        LHS        RHS   Support  Confidence      Lift
# 0  Display  OS and UI  0.196429    0.916667  3.019608
# 1  Display  OS and UI  0.196429    0.916667  3.019608
# 2  Display  OS and UI  0.160714    0.642857  3.000000
# 3  Display  OS and UI  0.196429    0.916667  3.019608
# 4  Display     Camera  0.160714    0.642857  3.000000

# %% [markdown]
# # Exporting the Data as CSV file

# %%
df.to_csv(r'C:\Users\New\Desktop\Implicit_Rule.csv', index = False)
